# %%
import modify_tools as mt

# %%
modify = mt.modify("data/江东快速路_15m.csv")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/草场门大街1_1_Points.xls")
dsm_list = modify.dsm.tolist()
modify.process_1(dsm_list)

# %%
modify = mt.modify("data/草场门大街2_Points.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/草场门大街1_1_Points.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/龙园东路.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/草场门大桥1_Points.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/江东隧道.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/江东隧道2.xls",threshold=2)
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/龙园西路.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/兴隆大街_Dissovle_GeneratePoints1_TableToExcel.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/梦都大街_Dissolve_GeneratePoints_TableToExcel.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/扬子江大道2_Dissolve_GeneratePoin_TableToExcel.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/保双街_Dissolve_GeneratePointsA_TableToExcel.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("data/龙园北路_Dissolve_GeneratePoints_TableToExcel.xls")
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)

# %%
modify = mt.modify("shp/梦都大街_Dissolve_GeneratePoints.shp",savefig=False,export_geo=True)
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)
# Out:
# C:\Users\Administrator\.conda\envs\ox\lib\site-packages\geopandas\io\file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
modify = mt.modify("data/仙林大道_Dissolve_GeneratePoints_TableToExcel.xls",savefig=False)
dsm_list = modify.dsm.tolist()
modify.process_2(dsm_list)
